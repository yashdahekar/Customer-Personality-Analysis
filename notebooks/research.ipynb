# %%
import pandas as pd

# %%
df = pd.read_csv('.\data\customer_data.csv')

# %%
df.sample(5)
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 1425   2428        1970  Graduation        Married  28164.0        1
# 1881   8341        1969         PhD        Married  30396.0        1
# 678    8779        1985    2n Cycle        Married  36145.0        1
# 210    2677        1956  Graduation       Together  46097.0        0
# 2129  10104        1974  Graduation       Together  33590.0        2
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumWebVisitsMonth  \
# 1425         0  2013-05-04       23         3  ...                  7
# 1881         0  2014-04-30       22        15  ...                  7
# 678          0  2013-06-16       13        56  ...                  9
# 210          1  2013-03-31       11        72  ...                  4
# 2129         1  2013-11-03       65         4  ...                  7
#
#       AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# ...
